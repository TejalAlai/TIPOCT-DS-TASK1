# %%
## Importing  libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
data = pd.read_csv("netflix.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4856 entries, 0 to 4855
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4856 non-null   object
#  1   High       4856 non-null   float64
#  2   Low        4856 non-null   float64
#  3   Open       4856 non-null   float64
#  4   Close      4856 non-null   float64
#  5   Volume     4856 non-null   float64
#  6   Adj Close  4856 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 265.7+ KB

# %%
data.head()
# Out:
#          Date      High       Low      Open     Close       Volume  Adj Close
# 0  2002-05-23  1.242857  1.145714  1.156429  1.196429  104790000.0   1.196429
# 1  2002-05-24  1.225000  1.197143  1.214286  1.210000   11104800.0   1.210000
# 2  2002-05-28  1.232143  1.157143  1.213571  1.157143    6609400.0   1.157143
# 3  2002-05-29  1.164286  1.085714  1.164286  1.103571    6757800.0   1.103571
# 4  2002-05-30  1.107857  1.071429  1.107857  1.071429   10154200.0   1.071429

# %%
data.tail()
# Out:
#             Date        High         Low        Open       Close     Volume  \
# 4851  2021-08-30  567.159973  556.450012  557.250000  566.179993  2434800.0
# 4852  2021-08-31  569.479980  561.609985  566.119995  569.190002  2431900.0
# 4853  2021-09-01  591.000000  569.000000  569.000000  582.070007  5626200.0
# 4854  2021-09-02  598.760010  583.679993  583.679993  588.549988  6179900.0
# 4855  2021-09-03  591.685120  583.140015  585.799988  589.520081  1589628.0
#
#        Adj Close
# 4851  566.179993
# 4852  569.190002
# 4853  582.070007
# 4854  588.549988
# 4855  589.520081

# %%
data.shape
# Out:
# (4856, 7)

# %%
data.nunique()
# Out:
# Date         4856
# High         4304
# Low          4292
# Open         4327
# Close        4390
# Volume       4717
# Adj Close    4390
# dtype: int64

# %%
data["Date"].unique()
# Out:
# array(['2002-05-23', '2002-05-24', '2002-05-28', ..., '2021-09-01',
#        '2021-09-02', '2021-09-03'], dtype=object)

# %%
print(data)
# Out:
#             Date        High         Low        Open       Close       Volume  \
# 0     2002-05-23    1.242857    1.145714    1.156429    1.196429  104790000.0
# 1     2002-05-24    1.225000    1.197143    1.214286    1.210000   11104800.0
# 2     2002-05-28    1.232143    1.157143    1.213571    1.157143    6609400.0
# 3     2002-05-29    1.164286    1.085714    1.164286    1.103571    6757800.0
# 4     2002-05-30    1.107857    1.071429    1.107857    1.071429   10154200.0
# ...          ...         ...         ...         ...         ...          ...
# 4851  2021-08-30  567.159973  556.450012  557.250000  566.179993    2434800.0
# 4852  2021-08-31  569.479980  561.609985  566.119995  569.190002    2431900.0
# 4853  2021-09-01  591.000000  569.000000  569.000000  582.070007    5626200.0
# 4854  2021-09-02  598.760010  583.679993  583.679993  588.549988    6179900.0
# 4855  2021-09-03  591.685120  583.140015  585.799988  589.520081    1589628.0
#
#        Adj Close
# ...

# %%
data.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  4856.000000  4856.000000  4856.000000  4856.000000  4.856000e+03
# mean    104.417595   101.223064   102.841799   102.882117  1.686502e+07
# std     155.588870   151.003701   153.329766   153.379795  1.939578e+07
# min       0.410714     0.346429     0.377857     0.372857  2.856000e+05
# 25%       3.971072     3.830357     3.892857     3.893929  6.333750e+06
# 50%      20.756429    20.010715    20.446428    20.429286  1.089410e+07
# 75%     125.750000   122.302502   124.007502   123.742502  2.021828e+07
# max     598.760010   583.679993   585.799988   589.520081  3.234140e+08
#
#          Adj Close
# count  4856.000000
# mean    102.882117
# std     153.379795
# min       0.372857
# 25%       3.893929
# 50%      20.429286
# 75%     123.742502
# max     589.520081

# %%
#summary statistic
data["Close"].describe()
# Out:
# count    4856.000000
# mean      102.882117
# std       153.379795
# min         0.372857
# 25%         3.893929
# 50%        20.429286
# 75%       123.742502
# max       589.520081
# Name: Close, dtype: float64

# %%
data.columns
# Out:
# Index(['Date', 'High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
df=data.corr()

# %%
df
# Out:
#                High       Low      Open     Close    Volume  Adj Close
# High       1.000000  0.999814  0.999862  0.999865 -0.244882   0.999865
# Low        0.999814  1.000000  0.999856  0.999859 -0.247588   0.999859
# Open       0.999862  0.999856  1.000000  0.999701 -0.246255   0.999701
# Close      0.999865  0.999859  0.999701  1.000000 -0.246122   1.000000
# Volume    -0.244882 -0.247588 -0.246255 -0.246122  1.000000  -0.246122
# Adj Close  0.999865  0.999859  0.999701  1.000000 -0.246122   1.000000

# %%
data.isnull().sum()
# Out:
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
#creating return series >>>>>> percentage change in share price is return
data["Return"]=data["Adj Close"].pct_change()

# %%
data.head()
# Out:
#          Date      High       Low      Open     Close       Volume  Adj Close  \
# 0  2002-05-23  1.242857  1.145714  1.156429  1.196429  104790000.0   1.196429
# 1  2002-05-24  1.225000  1.197143  1.214286  1.210000   11104800.0   1.210000
# 2  2002-05-28  1.232143  1.157143  1.213571  1.157143    6609400.0   1.157143
# 3  2002-05-29  1.164286  1.085714  1.164286  1.103571    6757800.0   1.103571
# 4  2002-05-30  1.107857  1.071429  1.107857  1.071429   10154200.0   1.071429
#
#      Return
# 0       NaN
# 1  0.011343
# 2 -0.043684
# 3 -0.046297
# 4 -0.029125

# %%
np.mean(data["Return"])
# Out:
# 0.0019190196260825982

# %%
# plotting closing prices

ax1 = data["Adj Close"].plot(style=["-"])

# %%
#plotting return

ax2 = data["Return"].plot(style=["-,g"])

# %%
data["Return"].hist()
# Out:
# <AxesSubplot:>

# %%
data["Adj Close"].hist()
# Out:
# <AxesSubplot:>

# %%
data["Close"].hist()
# Out:
# <AxesSubplot:>

# %%
data["High"].hist()
# Out:
# <AxesSubplot:>

# %%
data["Low"].hist()
# Out:
# <AxesSubplot:>

# %%
#kernel density
data["Adj Close"].plot(kind = "kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data["Return"].plot(kind = "kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data["Date"].describe()
# Out:
# count           4856
# unique          4856
# top       2002-07-19
# freq               1
# Name: Date, dtype: object

# %%
sns.pairplot(data)

# %%
sns.heatmap(df,annot=True)
# Out:
# <AxesSubplot:>
